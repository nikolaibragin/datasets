# %%
import numpy as np
import time
import os
from tqdm import tqdm
import pyarrow.parquet as pq
from sklearn.neighbors import KDTree
import json

# --- Configuration ---
DATA_FILE = "ad_features_all_gt1_14_08.parquet"
OUTPUT_FILE = "tde_nearest_neighbors_results_all_without_mean_variance.json"

# Target Object IDs for different categories can be uncommented as needed.
# TDE
TARGET_OBJECT_IDS = ['ZTF22abegjtx', 'ZTF22abkfhua', 'ZTF23aapyidj', 'ZTF23abohtqf', 'ZTF24aaecooj', 'ZTF24aajvvhj', 'ZTF24aakaiha', 'ZTF24aamfius', 'ZTF24aatxshz', 'ZTF24abfaake']
# SLNS
#TARGET_OBJECT_IDS = ['ZTF25aanxtou', 'ZTF25aaixrfr', 'ZTF24abvftmi', 'ZTF24abdhylt', 'ZTF24aaysowl', 'ZTF23aboebgh', 'ZTF23abcvbqq', 'ZTF23aanptpp', 'ZTF22abcvfgs', 'ZTF21ackxdos']
# CV
#TARGET_OBJECT_IDS = ['ZTF18abjcuhv', 'ZTF18aaudzmj', 'ZTF19aagxcga', 'ZTF18aaashju', 'ZTF21aagtpxy', 'ZTF18aboacjl', 'ZTF17aaantxj', 'ZTF18aajwgru', 'ZTF18abigrzf', 'ZTF18adibadz']

NUM_NEIGHBORS = 10

FEATURE_NAMES = [
    'mean_g', 'weighted_mean_g',
    'standard_deviation_g', 'median_g', 'amplitude_g', 'beyond_1_std_g',
    'cusum_g', 'inter_percentile_range_10_g', 'kurtosis_g', 'linear_trend_g',
    'linear_trend_sigma_g', 'linear_trend_noise_g', 'linear_fit_slope_g',
    'linear_fit_slope_sigma_g', 'linear_fit_reduced_chi2_g',
    'magnitude_percentage_ratio_40_5_g', 'magnitude_percentage_ratio_20_10_g',
    'maximum_slope_g', 'median_absolute_deviation_g',
    'median_buffer_range_percentage_10_g', 'percent_amplitude_g',
    'anderson_darling_normal_g', 'chi2_g', 'skew_g', 'stetson_K_g', 'mean_r',
    'weighted_mean_r', 'standard_deviation_r', 'median_r', 'amplitude_r',
    'beyond_1_std_r', 'cusum_r', 'inter_percentile_range_10_r', 'kurtosis_r',
    'linear_trend_r', 'linear_trend_sigma_r', 'linear_trend_noise_r',
    'linear_fit_slope_r', 'linear_fit_slope_sigma_r', 'linear_fit_reduced_chi2_r',
    'magnitude_percentage_ratio_40_5_r', 'magnitude_percentage_ratio_20_10_r',
    'maximum_slope_r', 'median_absolute_deviation_r',
    'median_buffer_range_percentage_10_r', 'percent_amplitude_r',
    'anderson_darling_normal_r', 'chi2_r', 'skew_r', 'stetson_K_r', 'distnr'
]

def load_and_prepare_data_parquet(filepath):

    print(f"Step 1: Reading data from '{filepath}'...")
    try:
        pq_file = pq.ParquetFile(filepath)
    except Exception as e:
        print(f" ERROR: Could not open Parquet file '{filepath}'. {e}"); return None, None

    num_objects_initial = pq_file.metadata.num_rows
    print(f"   The file contains {num_objects_initial:,} objects.")

    object_ids_list, feature_batches = [], []
    columns_to_read = ['objectId'] + FEATURE_NAMES

    for i in tqdm(range(pq_file.num_row_groups), desc="Reading Parquet batches"):
        batch = pq_file.read_row_group(i, columns=columns_to_read)
        object_ids_list.extend(batch.column('objectId').to_pylist())
        feature_batches.append(np.column_stack([batch.column(name).to_numpy() for name in FEATURE_NAMES]))

    print("Combining batches...")
    data_matrix = np.vstack(feature_batches).astype('float32')
    object_ids = np.array(object_ids_list)
    print(f" Data loaded. Matrix size: {data_matrix.shape}")

    print("\nStep 2: Removing rows containing NaN...")
    nan_mask = np.isnan(data_matrix).any(axis=1)
    num_nan_rows = np.sum(nan_mask)

    if num_nan_rows > 0:
        print(f"   Found {num_nan_rows:,} rows with NaN values. Removing them...")
        data_matrix = data_matrix[~nan_mask]
        object_ids = object_ids[~nan_mask]
        print(f"Cleanup complete. Matrix size after cleanup: {data_matrix.shape}")
    else:
        print("No missing values (NaN) found.")

    print("\n Step 3: Normalizing data (Standardization)...")
    mean = np.mean(data_matrix, axis=0, dtype='float32')
    std = np.std(data_matrix, axis=0, dtype='float32')
    std[std == 0] = 1.0
    data_matrix = (data_matrix - mean) / std
    print("Data successfully normalized.")

    return object_ids.tolist(), data_matrix

def find_neighbors_kdtree_batch(data, query_vectors, k_candidates):
    """
    Builds a KD-Tree on the CPU and performs a batch search.
    """
    print("\nStep 4: Building KD-Tree...")
    print("   (This may take a few minutes depending on data size and CPU power)")
    start_time = time.time()
    kdt = KDTree(data, leaf_size=40, metric='euclidean')
    end_time = time.time()
    print(f"Tree built in {end_time - start_time:.2f} sec.")

    print(f"\nPerforming batch search for {len(query_vectors)} objects...")
    start_time = time.time()
    distances, indices = kdt.query(query_vectors, k=k_candidates)
    end_time = time.time()
    print(f"Search completed in {end_time - start_time:.4f} sec.")

    return distances, indices

# --- Main execution block ---
if __name__ == "__main__":
    if not os.path.exists(DATA_FILE):
        print(f"ERROR: Data file '{DATA_FILE}' not found.")
        exit()

    all_ids, norm_data = load_and_prepare_data_parquet(DATA_FILE)
    if all_ids is None:
        exit()

    print("\nStep 5: Finding target objects and preparing query vectors...")
    id_to_idx = {oid: i for i, oid in enumerate(all_ids)}

    query_vectors_list, found_target_ids = [], []
    for target_id in TARGET_OBJECT_IDS:
        if target_id in id_to_idx:
            query_vectors_list.append(norm_data[id_to_idx[target_id]])
            found_target_ids.append(target_id)
        else:
            print(f"   Warning: Target object '{target_id}' not found in the data (possibly removed due to NaN) and will be skipped.")

    if not found_target_ids:
        print("ERROR: None of the target objects were found in the cleaned data. Exiting.")
        exit()

    query_vectors = np.array(query_vectors_list, dtype='float32')
    print(f"Found {len(found_target_ids)} target objects. Preparing to search.")

    distances_raw, indices_raw = find_neighbors_kdtree_batch(norm_data, query_vectors, NUM_NEIGHBORS + 1)

    print("\n" + "="*80)
    print("NEAREST NEIGHBOR SEARCH RESULTS (KD-Tree algorithm, data cleaned of NaN)")
    print("="*80)

    results_to_save = {}

    for i, target_id in enumerate(found_target_ids):
        final_neighbors_for_print = []
        final_neighbor_ids_for_json = []
        seen_ids = {target_id}

        distances_for_target, indices_for_target = distances_raw[i], indices_raw[i]

        for j in range(len(indices_for_target)):
            if len(final_neighbor_ids_for_json) >= NUM_NEIGHBORS:
                break

            neighbor_id = all_ids[indices_for_target[j]]
            if neighbor_id in seen_ids:
                continue
            
            final_neighbor_ids_for_json.append(neighbor_id)
            
            neighbor_dist = distances_for_target[j]
            final_neighbors_for_print.append({'id': neighbor_id, 'distance': neighbor_dist})
            
            seen_ids.add(neighbor_id)
        
        results_to_save[target_id] = final_neighbor_ids_for_json

        print(f"\n--- {NUM_NEIGHBORS} nearest unique neighbors for: {target_id} ---\n")
        print(f"{'Rank':<5} {'ObjectID':<20} {'L2 Distance':<20}")
        print("-"*50)
        for rank, neighbor in enumerate(final_neighbors_for_print, 1):
            print(f"{rank:<5} {neighbor['id']:<20} {neighbor['distance']:<20.4f}")

    print("\n" + "="*80)
    print(f"Saving results to file '{OUTPUT_FILE}'...")
    try:
        with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(results_to_save, f, indent=4)
        print(f"Results successfully saved.")
    except Exception as e:
        print(f"ERROR: Could not save the file. {e}")

    print("\n" + "="*80)
# Out:
# Step 1: Reading data from 'ad_features_all_gt1_14_08.parquet'...
#    The file contains 3,922,520 objects.
# Reading Parquet batches: 100%|████████████████████| 1/1 [00:08<00:00,  8.02s/it]
# Combining batches...
#  Data loaded. Matrix size: (3922520, 51)
#
# Step 2: Removing rows containing NaN...
#    Found 3,642,757 rows with NaN values. Removing them...
# Cleanup complete. Matrix size after cleanup: (279763, 51)
#
#  Step 3: Normalizing data (Standardization)...
# Data successfully normalized.
#
# Step 5: Finding target objects and preparing query vectors...
#    Warning: Target object 'ZTF18abjcuhv' not found in the data (possibly removed due to NaN) and will be skipped.
#    Warning: Target object 'ZTF18aaudzmj' not found in the data (possibly removed due to NaN) and will be skipped.
#    Warning: Target object 'ZTF19aagxcga' not found in the data (possibly removed due to NaN) and will be skipped.
#    Warning: Target object 'ZTF18aaashju' not found in the data (possibly removed due to NaN) and will be skipped.
#    Warning: Target object 'ZTF21aagtpxy' not found in the data (possibly removed due to NaN) and will be skipped.
#    Warning: Target object 'ZTF17aaantxj' not found in the data (possibly removed due to NaN) and will be skipped.
# Found 4 target objects. Preparing to search.
#
# Step 4: Building KD-Tree...
#    (This may take a few minutes depending on data size and CPU power)
# Tree built in 1.69 sec.
#
# Performing batch search for 4 objects...
# Search completed in 0.0992 sec.
#
# ================================================================================
# NEAREST NEIGHBOR SEARCH RESULTS (KD-Tree algorithm, data cleaned of NaN)
# ================================================================================
#
# --- 100 nearest unique neighbors for: ZTF18aboacjl ---
#
# Rank  ObjectID             L2 Distance
# --------------------------------------------------
# 1     ZTF18abwbjjy         15.6274
# 2     ZTF17aaajeks         16.6986
# 3     ZTF18aazsdnv         16.8160
# 4     ZTF18absnnsr         18.7939
# 5     ZTF18ablxnta         18.9651
# 6     ZTF20acwtodw         19.4417
# 7     ZTF18abwsres         21.1598
# 8     ZTF18abpptwd         23.2860
# 9     ZTF18abmbdgo         23.4681
# 10    ZTF18acpxfxr         24.0425
# 11    ZTF18aaisedb         24.1133
# 12    ZTF25aabxbwg         24.4977
# 13    ZTF18acrxnze         24.7169
# 14    ZTF18acbbxdx         24.8536
# 15    ZTF18abddimk         25.0237
# 16    ZTF18acvvedi         25.7462
# 17    ZTF18acxgvqt         25.8383
# 18    ZTF17aabveay         26.0581
# 19    ZTF18acqxeba         26.2512
# 20    ZTF19aayhseh         26.3931
# 21    ZTF19ackxdpk         26.7337
# 22    ZTF19adddglq         26.8256
# 23    ZTF18abuhqfi         27.0940
# 24    ZTF18abjgdih         27.2081
# 25    ZTF19aavznib         27.2870
# 26    ZTF18aabjrvh         27.3296
# 27    ZTF17aabvwuk         27.8150
# 28    ZTF18adalkyr         28.4593
# 29    ZTF18abvceiu         28.6089
# 30    ZTF17aaarpiq         28.8304
# 31    ZTF20abjckje         28.9068
# 32    ZTF19aatuwke         29.0838
# 33    ZTF23abigaao         29.1664
# 34    ZTF18adjsnqi         29.2327
# 35    ZTF18abmahbc         29.3187
# 36    ZTF17aaahsjn         29.5604
# 37    ZTF18adkowqk         29.5670
# 38    ZTF19aakplui         29.6661
# 39    ZTF18adalkwp         29.8322
# 40    ZTF20aakyijk         29.9653
# 41    ZTF18aavegci         29.9792
# 42    ZTF19aaylohn         30.2406
# 43    ZTF18acucsxw         30.3421
# 44    ZTF19aaaqmyg         30.3791
# 45    ZTF18aajtkma         30.4340
# 46    ZTF20acwugkm         30.5846
# 47    ZTF18aabeetp         30.7113
# 48    ZTF25aawlutq         30.7423
# 49    ZTF23aasoovm         30.8894
# 50    ZTF19aaufuht         31.0958
# 51    ZTF19aagzlnb         31.1712
# 52    ZTF19aavagtp         31.3885
# 53    ZTF18aabiwpi         31.4586
# 54    ZTF19abpnldk         31.6808
# 55    ZTF17aaaryiz         31.7260
# 56    ZTF17aabtjmc         31.7698
# 57    ZTF19aalkylm         31.7809
# 58    ZTF19aadunjh         31.8214
# 59    ZTF18aauegwi         31.8491
# 60    ZTF20abweufc         31.9500
# 61    ZTF18abnozzo         32.0530
# 62    ZTF18adllvct         32.1689
# 63    ZTF18aampffv         32.1752
# 64    ZTF18actauvk         32.3158
# 65    ZTF18acrukig         32.3352
# 66    ZTF18aaaihby         32.3440
# 67    ZTF21aaettwf         32.3848
# 68    ZTF18adkxytt         32.4125
# 69    ZTF20abewxfh         32.4147
# 70    ZTF18abtmeie         32.5093
# 71    ZTF18abskrrt         32.5407
# 72    ZTF18acaxrxx         32.6073
# 73    ZTF18abaelhm         32.6492
# 74    ZTF19abmypfs         32.9653
# 75    ZTF19acbpeiv         33.0676
# 76    ZTF18acufkmm         33.1284
# 77    ZTF18acewnmo         33.1726
# 78    ZTF18abhbyii         33.1756
# 79    ZTF19aakjfgd         33.4031
# 80    ZTF19aaiqqzk         33.4359
# 81    ZTF18abcxrcp         33.5086
# 82    ZTF17aabxzol         33.5385
# 83    ZTF18aayzpbr         33.5679
# 84    ZTF18aczexyf         33.5810
# 85    ZTF19aaxkgwa         33.6264
# 86    ZTF20aaedndo         33.6383
# 87    ZTF18adkhuxp         33.6711
# 88    ZTF19aaydqet         33.6850
# 89    ZTF18aahhetu         33.7097
# 90    ZTF18ablrndt         33.7236
# 91    ZTF19aazcclj         33.7742
# 92    ZTF23aamnvwf         33.8511
# 93    ZTF18abgivby         33.8595
# 94    ZTF18abineel         33.8856
# 95    ZTF20abywqqb         33.8903
# 96    ZTF19aakryxs         33.9763
# 97    ZTF17aaapiii         34.0652
# 98    ZTF18adacfym         34.0955
# 99    ZTF18abcildf         34.1088
# 100   ZTF19aaaqqaj         34.1319
#
# --- 100 nearest unique neighbors for: ZTF18aajwgru ---
#
# Rank  ObjectID             L2 Distance
# --------------------------------------------------
# 1     ZTF24abalazn         1.5302
# 2     ZTF18aajgtjr         1.9286
# 3     ZTF23aaefwuc         1.9530
# 4     ZTF22abkewft         1.9774
# 5     ZTF20aaozusw         1.9887
# 6     ZTF20ablevik         2.0779
# 7     ZTF19abtnqdj         2.0795
# 8     ZTF21abqscdd         2.2053
# 9     ZTF23aaobtbl         2.2370
# 10    ZTF21acdvtmq         2.2516
# 11    ZTF19abfhret         2.2520
# 12    ZTF24ablpgzn         2.2541
# 13    ZTF19ablgofw         2.2890
# 14    ZTF19aapwaeh         2.2956
# 15    ZTF20aclqsfk         2.3026
# 16    ZTF22aagpqoy         2.3191
# 17    ZTF23abbozbe         2.3235
# 18    ZTF19aaddjyn         2.3537
# 19    ZTF19acdpetc         2.3614
# 20    ZTF24abzwzin         2.3714
# 21    ZTF18aasxtdj         2.3745
# 22    ZTF23aarlfak         2.3937
# 23    ZTF24abaqzuy         2.3995
# 24    ZTF22aawodgv         2.4048
# 25    ZTF25aayyrnx         2.4058
# 26    ZTF21abbscsf         2.4095
# 27    ZTF25aapjvle         2.4147
# 28    ZTF22abjurjx         2.4214
# 29    ZTF22aagavue         2.4317
# 30    ZTF23aahijsn         2.4454
# 31    ZTF18aastkcw         2.4468
# 32    ZTF23aawyqmo         2.4472
# 33    ZTF21absspyt         2.4653
# 34    ZTF20acigotw         2.4684
# 35    ZTF21acmiysn         2.4720
# 36    ZTF23aatlztn         2.4770
# 37    ZTF20abppbie         2.4790
# 38    ZTF25aaxltcl         2.4833
# 39    ZTF25aaaiuws         2.4910
# 40    ZTF19abdqfcs         2.4964
# 41    ZTF22abqnura         2.4998
# 42    ZTF20abmrxro         2.5021
# 43    ZTF24absmntg         2.5095
# 44    ZTF20accxwsf         2.5109
# 45    ZTF25aapcllt         2.5159
# 46    ZTF20achywtm         2.5210
# 47    ZTF20acezgmr         2.5229
# 48    ZTF20abmkron         2.5338
# 49    ZTF20aaxkalw         2.5348
# 50    ZTF25aanlexz         2.5495
# 51    ZTF25aadcfqv         2.5538
# 52    ZTF21ackunpu         2.5568
# 53    ZTF18abvtotw         2.5576
# 54    ZTF23aafmslw         2.5613
# 55    ZTF20abjahne         2.5737
# 56    ZTF24aauunxv         2.5793
# 57    ZTF23aanjnvx         2.5863
# 58    ZTF19abjfrcu         2.6025
# 59    ZTF20aapcbdj         2.6073
# 60    ZTF21aazzwul         2.6081
# 61    ZTF20aazqpwh         2.6177
# 62    ZTF20abhtsaz         2.6225
# 63    ZTF19aapvzxy         2.6236
# 64    ZTF20acmfagy         2.6445
# 65    ZTF23abtmhvn         2.6500
# 66    ZTF18abvpkyp         2.6512
# 67    ZTF23abfttav         2.6649
# 68    ZTF20aalqxjv         2.6702
# 69    ZTF25aarsoza         2.6813
# 70    ZTF20abfflqh         2.6828
# 71    ZTF23aampbze         2.6870
# 72    ZTF23aahoikg         2.6877
# 73    ZTF21abdtwmn         2.6894
# 74    ZTF20abwbcbs         2.6954
# 75    ZTF20abbzeko         2.7033
# 76    ZTF20actnqzc         2.7079
# 77    ZTF24absibto         2.7082
# 78    ZTF24aayxeji         2.7118
# 79    ZTF20aciuxqf         2.7151
# 80    ZTF20aadbfue         2.7200
# 81    ZTF21aafkvbg         2.7372
# 82    ZTF19acolbgw         2.7379
# 83    ZTF18aavuojt         2.7462
# 84    ZTF21aajxkum         2.7492
# 85    ZTF19aaleqdt         2.7562
# 86    ZTF24abkmdue         2.7605
# 87    ZTF24abkknhx         2.7611
# 88    ZTF22abzyghh         2.7636
# 89    ZTF20aajsyts         2.7647
# 90    ZTF23abtxsuo         2.7681
# 91    ZTF24abamagk         2.7709
# 92    ZTF21abbgirp         2.7727
# 93    ZTF19abkfheu         2.7750
# 94    ZTF23aagvpid         2.7771
# 95    ZTF21aaokary         2.7777
# 96    ZTF22aasevpz         2.7833
# 97    ZTF20abmkezr         2.7848
# 98    ZTF19abcfgyk         2.7892
# 99    ZTF20abntfde         2.7971
# 100   ZTF23abtnhif         2.7998
#
# --- 100 nearest unique neighbors for: ZTF18abigrzf ---
#
# Rank  ObjectID             L2 Distance
# --------------------------------------------------
# 1     ZTF18absutld         2.2271
# 2     ZTF20aaithky         2.3501
# 3     ZTF17aaaazpg         2.3523
# 4     ZTF20acpcjek         2.4672
# 5     ZTF18abclsrz         2.4751
# 6     ZTF18ablqmrk         2.4937
# 7     ZTF18abirbon         2.6108
# 8     ZTF23aacsysw         2.6468
# 9     ZTF18absqjju         2.6524
# 10    ZTF18abnowzp         2.6926
# 11    ZTF18abdrmzl         2.7004
# 12    ZTF23aambeoi         2.7131
# 13    ZTF18adkmaqw         2.7136
# 14    ZTF20aabpmly         2.7158
# 15    ZTF19adcneur         2.7334
# 16    ZTF18abccmny         2.7389
# 17    ZTF19achudxk         2.7561
# 18    ZTF19aanyiwh         2.7568
# 19    ZTF19aaxnxqe         2.7590
# 20    ZTF18abxpeud         2.7753
# 21    ZTF18adnnwju         2.7935
# 22    ZTF18adqibwq         2.7942
# 23    ZTF18abkhkwp         2.7975
# 24    ZTF19abqtfst         2.7992
# 25    ZTF18aaxmxqy         2.8286
# 26    ZTF18acgrill         2.8305
# 27    ZTF18acwvirj         2.8308
# 28    ZTF19abjfxgh         2.8401
# 29    ZTF18aakgwbu         2.8473
# 30    ZTF22aadbnwn         2.8663
# 31    ZTF18absidbe         2.8681
# 32    ZTF18aceihca         2.8769
# 33    ZTF22aalacre         2.8840
# 34    ZTF18abuelqu         2.8865
# 35    ZTF22aakpetm         2.8915
# 36    ZTF19aauxzen         2.8991
# 37    ZTF18abrxxko         2.9038
# 38    ZTF18acvtxvf         2.9064
# 39    ZTF18abhxwuj         2.9108
# 40    ZTF18abmgxck         2.9111
# 41    ZTF18aazvkvz         2.9134
# 42    ZTF18aaylcic         2.9138
# 43    ZTF21aaplvcg         2.9157
# 44    ZTF18adkhtsz         2.9197
# 45    ZTF18aczddvt         2.9202
# 46    ZTF22aaakjkw         2.9212
# 47    ZTF23aavuner         2.9233
# 48    ZTF18abnpcey         2.9248
# 49    ZTF22aaimdzz         2.9306
# 50    ZTF18aczogcn         2.9401
# 51    ZTF24abmgbar         2.9435
# 52    ZTF18aasnmuh         2.9437
# 53    ZTF18abnpgnz         2.9514
# 54    ZTF18abcmtbn         2.9516
# 55    ZTF18abnugna         2.9531
# 56    ZTF18adoavyx         2.9540
# 57    ZTF18abgddnv         2.9568
# 58    ZTF23aafnllv         2.9684
# 59    ZTF18abcvnqb         2.9752
# 60    ZTF18abimzsm         2.9752
# 61    ZTF18acjbazd         2.9790
# 62    ZTF20acfcisg         2.9825
# 63    ZTF18aaxcqgj         2.9837
# 64    ZTF18abusppt         2.9853
# 65    ZTF19abqtlks         2.9872
# 66    ZTF23aabkyww         2.9882
# 67    ZTF18adkoavs         2.9890
# 68    ZTF19aamwrxm         2.9901
# 69    ZTF18absurbv         2.9931
# 70    ZTF20acxkhja         2.9943
# 71    ZTF18abfjrtq         2.9946
# 72    ZTF20abjbpti         2.9972
# 73    ZTF19acgquoi         3.0031
# 74    ZTF18abssevf         3.0031
# 75    ZTF19abzzscu         3.0034
# 76    ZTF19abwfttz         3.0038
# 77    ZTF20abjnajr         3.0049
# 78    ZTF18abdfqxb         3.0051
# 79    ZTF18aagxcws         3.0064
# 80    ZTF18abvwren         3.0084
# 81    ZTF20aabluow         3.0091
# 82    ZTF18aczclot         3.0180
# 83    ZTF18abssexw         3.0184
# 84    ZTF21acrebxz         3.0193
# 85    ZTF18abcddkg         3.0204
# 86    ZTF17aabwdqx         3.0209
# 87    ZTF18abcwkej         3.0216
# 88    ZTF18abpmwvu         3.0240
# 89    ZTF18abqxcoi         3.0248
# 90    ZTF18abcxqrd         3.0258
# 91    ZTF18absbkcn         3.0262
# 92    ZTF23abqgucp         3.0265
# 93    ZTF22aapepgs         3.0268
# 94    ZTF18aayxqrl         3.0277
# 95    ZTF19aatvpou         3.0304
# 96    ZTF21abqmfrk         3.0312
# 97    ZTF23aaavfyt         3.0431
# 98    ZTF18abcgmdg         3.0474
# 99    ZTF18abnpyab         3.0478
# 100   ZTF18acryinn         3.0504
#
# --- 100 nearest unique neighbors for: ZTF18adibadz ---
#
# Rank  ObjectID             L2 Distance
# --------------------------------------------------
# 1     ZTF18abmnmuw         2.9801
# 2     ZTF18aayeany         3.0833
# 3     ZTF17aaadpbl         3.0912
# 4     ZTF18aawbjux         3.1344
# 5     ZTF18abinrqm         3.1921
# 6     ZTF18admfxgo         3.2753
# 7     ZTF18adljdzj         3.2906
# 8     ZTF18abmaifq         3.3002
# 9     ZTF17aabumlb         3.3097
# 10    ZTF18abdlgim         3.3241
# 11    ZTF18ablwzkz         3.3659
# 12    ZTF19acekpoy         3.3715
# 13    ZTF18abgerbf         3.3814
# 14    ZTF18aayecxh         3.3935
# 15    ZTF18abecmfw         3.3974
# 16    ZTF18abegpcf         3.4112
# 17    ZTF18abpogbj         3.4655
# 18    ZTF18ablvsmu         3.5079
# 19    ZTF18abpqcri         3.5488
# 20    ZTF18abwnepa         3.5493
# 21    ZTF18abpmxun         3.5583
# 22    ZTF18abudvxq         3.5667
# 23    ZTF18abjrcno         3.5751
# 24    ZTF18abiyjyq         3.5961
# 25    ZTF18ababllf         3.6018
# 26    ZTF18aaxyrcf         3.6053
# 27    ZTF21aauvyod         3.6213
# 28    ZTF18abpfkfi         3.6408
# 29    ZTF18adkrlgg         3.6423
# 30    ZTF18abdeayz         3.6506
# 31    ZTF19aafozmp         3.6519
# 32    ZTF18admfskw         3.6667
# 33    ZTF18adksjgk         3.6734
# 34    ZTF18abotzdb         3.6744
# 35    ZTF18abnppui         3.6791
# 36    ZTF18abztcib         3.6946
# 37    ZTF18abmaolz         3.7044
# 38    ZTF18abmddrh         3.7120
# 39    ZTF19aawkymc         3.7291
# 40    ZTF18aarwvdb         3.7429
# 41    ZTF18aayfbqp         3.7612
# 42    ZTF19aayymvz         3.7655
# 43    ZTF18admakjf         3.7706
# 44    ZTF18abcgmiq         3.7719
# 45    ZTF18abpfilx         3.7912
# 46    ZTF18ablrsex         3.7918
# 47    ZTF23aaqazhf         3.7952
# 48    ZTF18abppxkx         3.8035
# 49    ZTF18abpmxph         3.8039
# 50    ZTF18abmrdxt         3.8051
# 51    ZTF18abfxrtf         3.8137
# 52    ZTF18abbwtmh         3.8195
# 53    ZTF18abbnsmi         3.8239
# 54    ZTF18adqovuq         3.8408
# 55    ZTF18aawaddl         3.8676
# 56    ZTF18abbslav         3.8862
# 57    ZTF19abagbhc         3.8862
# 58    ZTF19adighli         3.8933
# 59    ZTF18abbxjbv         3.8935
# 60    ZTF19aafnnko         3.8993
# 61    ZTF18ablxbmc         3.9107
# 62    ZTF25aaiusko         3.9151
# 63    ZTF18abstbam         3.9179
# 64    ZTF19aarguqt         3.9351
# 65    ZTF19aagjgnd         3.9398
# 66    ZTF18abmefdn         3.9562
# 67    ZTF18adlvxfb         3.9601
# 68    ZTF18abjhaxw         3.9623
# 69    ZTF18ablvaet         3.9691
# 70    ZTF19aapqgya         3.9721
# 71    ZTF19aatufxh         3.9778
# 72    ZTF18ablwvnd         3.9829
# 73    ZTF18abpfgnz         3.9879
# 74    ZTF18admasrt         4.0005
# 75    ZTF18abellwe         4.0060
# 76    ZTF18aazlxkq         4.0087
# 77    ZTF19aafntwq         4.0137
# 78    ZTF18abiqogd         4.0243
# 79    ZTF18abjdnor         4.0385
# 80    ZTF19aaylsqv         4.0395
# 81    ZTF19aafntcy         4.0480
# 82    ZTF19aafnnwa         4.0524
# 83    ZTF18adkgjem         4.0573
# 84    ZTF19aaejuhk         4.0628
# 85    ZTF18abcgmen         4.0634
# 86    ZTF18adlwzib         4.0666
# 87    ZTF18abpptlr         4.0684
# 88    ZTF18abajciw         4.0706
# 89    ZTF17aaawcte         4.0737
# 90    ZTF23aazmlho         4.0737
# 91    ZTF18abbwwoo         4.0797
# 92    ZTF18abcikxt         4.0847
# 93    ZTF18abucnop         4.0872
# 94    ZTF18abcocto         4.0891
# 95    ZTF18adbipyx         4.0891
# 96    ZTF18abghqhh         4.0936
# 97    ZTF18abgqdta         4.0940
# 98    ZTF18abvombs         4.0953
# 99    ZTF18abfitoz         4.1021
# 100   ZTF18abnpcdu         4.1027
#
# ================================================================================
# Saving results to file 'cv_nearest_neighbors_results_all_without_mean_variance_r.json'...
# Results successfully saved.
#
# ================================================================================
